# %%
import re
import time
import requests
from datetime import datetime
from Proxies import Proxies
import logging
import requests
import jsonpath
import random
import json
import time

headers = {
    'Connection': 'keep-alive',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'Accept-Encoding': 'gzip, deflate',
    'Accept-Language': 'zh-CN,zh;q=0.9',
}

# %%
# category2_url = f'https://api.sidelineswap.com/v2/facet_items?category%5B%5D={i[0]}'
#         req2=requests.get(url=category2_url, headers=headers, timeout=100, verify=False)
#         category2_info = re.findall('"children":(.*)', req2.text)[0]
#         category2_kv = re.findall('"id":(.*?),"name":"(.*?)"', category1_info)

# %%
def get_category(category1_url, start, end):
    req=requests.get(url=category1_url, headers=headers, timeout=100, verify=False)
    category1_info = re.findall('"children":(.*)', req.text)[0]
    category1_kv = re.findall('"id":(.*?),"name":"(.*?)"', category1_info)
    category1_dict = {}
    for i in category1_kv[start:end]:
        key = i[1].replace(' \\u0026','')
        category1_dict[key] = i[0]
    return category1_dict

# %%
category1_url = 'https://api.sidelineswap.com/v2/facet_items'
ca1 = get_category(category1_url, 0, 31)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.sidelineswap.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
ca1
# Out:
# {'Golf': '7000',
#  'Apparel': '110165',
#  'Hockey': '2000',
#  'Baseball': '4000',
#  'Footwear': '110231',
#  'Lacrosse': '1000',
#  'Skiing': '3000',
#  'Softball': '10000',
#  'Football': '6000',
#  'Memorabilia': '110730',
#  'Snowboarding': '8000',
#  'Soccer': '9000',
#  'Inline, Roller Street Hockey': '110662',
#  'Tennis Racquet Sports': '110153',
#  'Bikes': '110000',
#  'Fitness Training': '110628',
#  'Basketball': '5000',
#  'Surf, Wake Water Sports': '110599',
#  'Other': '110173',
#  'Disc Golf': '110612',
#  "Women's Lacrosse": '101003',
#  'Figure Skating': '110574',
#  'Electronics, Gaming Esports': '110639',
#  'Skateboarding': '110626',
#  'Motocross': '110174',
#  'Hike Camp': '110475',
#  'Field Hockey': '110576',
#  'Snowshoe': '110586',
#  'Fishing': '110621',
#  'Wrestling': '110605',
#  'Paintball': '110655'}

# %%
category2_url = f'https://api.sidelineswap.com/v2/facet_items?category%5B%5D={ca1["Apparel"]}'
Apparel_ca2 = get_category(category2_url, 1, 18)
Apparel_ca2
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'Jackets Coats': '110225',
#  'Jerseys': '110219',
#  'Hats': '110224',
#  'Shirts': '110223',
#  'Face Masks Coverings': '110722',
#  'Sweatshirts Hoodies': '110227',
#  'Base Layers Compression': '110220',
#  'Pants': '110221',
#  'Shorts': '110222',
#  'Vests': '110240',
#  'Winter Gloves': '110226',
#  'Socks': '110228',
#  'Sunglasses': '110229',
#  'Swimsuits': '110615',
#  'Backpacks Bags': '110616',
#  'Other': '110230',
#  'Scarves': '110870'}

# %%
category2_url = f'https://api.sidelineswap.com/v2/facet_items?category%5B%5D={ca1["Golf"]}'
Golf_ca2 = get_category(category2_url, 1, 12)
Golf_ca2
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'Clubs': '110430',
#  'Shafts': '110078',
#  'Grips': '110079',
#  'Bags Carts': '110437',
#  'Shoes': '110073',
#  'Balls': '110082',
#  'Headcovers': '110435',
#  'On-Course': '110417',
#  'Other': '110076',
#  'Technology': '110446',
#  'Training Aids': '110436'}

# %%
category2_url = f'https://api.sidelineswap.com/v2/facet_items?category%5B%5D={110430}'
Clubs_ca3 = get_category(category2_url, 2, 12)
Clubs_ca3
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.sidelineswap.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'Drivers': '110065',
#  'Fairway Woods': '110066',
#  'Hybrids': '110067',
#  'Iron Sets': '110068',
#  'Complete Sets': '110077',
#  'Single Irons': '110081',
#  'Wedges': '110069',
#  'Putters': '110070',
#  'Club Heads': '110432',
#  'Assorted Golf Clubs': '110728'}

# %%
category1_dict = {'Apparel': '110165',
 'Golf': '7000',
 'Hockey': '2000',
 'Baseball': '4000',
 'Footwear': '110231',
 'Lacrosse': '1000',
 'Skiing': '3000',
 'Softball': '10000',
 'Football': '6000',
 'Memorabilia': '110730',
 'Snowboarding': '8000',
 'Soccer': '9000',
 'Inline, Roller Street Hockey': '110662',
 'Tennis Racquet Sports': '110153',
 'Bikes': '110000',
 'Fitness Training': '110628',
 'Basketball': '5000',
 'Surf, Wake Water Sports': '110599',
 'Other': '110173',
 'Disc Golf': '110612',
 "Women's Lacrosse": '101003',
 'Figure Skating': '110574',
 'Electronics, Gaming Esports': '110639',
 'Skateboarding': '110626',
 'Motocross': '110174',
 'Hike Camp': '110475',
 'Snowshoe': '110586',
 'Field Hockey': '110576',
 'Wrestling': '110605',
 'Fishing': '110621',
 'Paintball': '110655'}

# %%
category_mix_dict = {'Jackets Coats': '110225',
 'Jerseys': '110219',
 'Hats': '110224',
 'Shirts': '110223',
 'Face Masks Coverings': '110722',
 'Sweatshirts Hoodies': '110227',
 'Base Layers Compression': '110220',
 'Pants': '110221',
 'Shorts': '110222',
 'Vests': '110240',
 'Winter Gloves': '110226',
 'Socks': '110228',
 'Sunglasses': '110229',
 'Swimsuits': '110615',
 'Backpacks Bags': '110616',
 'Other': '110230',
 'Scarves': '110870',
 'Clubs': '110430',
 'Shafts': '110078',
 'Grips': '110079',
 'Bags Carts': '110437',
 'Shoes': '110073',
 'Balls': '110082',
 'Headcovers': '110435',
 'On-Course': '110417',
 'Other': '110076',
 'Technology': '110446',
 'Training Aids': '110436',
 'Hockey': '2000',
 'Baseball': '4000',
 'Footwear': '110231',
 'Lacrosse': '1000',
 'Skiing': '3000',
 'Softball': '10000',
 'Football': '6000',
 'Memorabilia': '110730',
 'Snowboarding': '8000',
 'Soccer': '9000',
 'Inline, Roller Street Hockey': '110662',
 'Tennis Racquet Sports': '110153',
 'Bikes': '110000',
 'Fitness Training': '110628',
 'Basketball': '5000',
 'Surf, Wake Water Sports': '110599',
 'Other': '110173',
 'Disc Golf': '110612',
 "Women's Lacrosse": '101003',
 'Figure Skating': '110574',
 'Electronics, Gaming Esports': '110639',
 'Skateboarding': '110626',
 'Motocross': '110174',
 'Hike Camp': '110475',
 'Snowshoe': '110586',
 'Field Hockey': '110576',
 'Wrestling': '110605',
 'Fishing': '110621',
 'Paintball': '110655'}

# %%
#request函数
def httget(url):
    # 防止请求过快
    time.sleep(random.randint(1, 5))
    for i in range(5):
        try:
            body=requests.get(url=url, headers=headers, timeout=100, verify=False)
            body.encoding='utf-8'
            print(i, body.status_code)
            if body.status_code == 200:
                return body.json()
            time.sleep(120)
        except Exception as e:
            time.sleep(120)
    return None

#爬虫函数
def crawl(file_name, url, category1_dict, pages=50):
    with open(file_name, 'w+', encoding='utf-8') as f:
        for category in category1_dict.items():
            category_num = 0
            print(f'*{category[0]} is running...........')
            category_url = url + f'&category%5B%5D={category[1]}'
            # 翻页
            for page in range(1, pages + 1):
                print(f'**{category[0]} page-{page} is running...........')
                page_url = category_url + f'&page={page}'
                page_res = httget(page_url)
                json_data = jsonpath.jsonpath(page_res, '$.data')[0]
                for line in json_data:
                    f.write(json.dumps(line, ensure_ascii=False))
                    f.write('\n')
                category_num += len(json_data)  
                print(f'*{category[0]} is {category_num}>>>>>>>>>>>>>>>>>>>>>')
                if len(json_data) < 5000:
                    break

# %%
import requests
from pyquery import PyQuery

class Proxy_getdata:
    def __init__(self, pages, headers, url='http://www.ip3366.net/?stype=1'):
        self.pages = pages
        self.headers = headers
        self.url = url

    #爬取代理ip
    def crawl_proxy(self, verify_url):
        pages = self.pages
        url = self.url
        headers = self.headers
        for page in range(pages):
            page_url = url + f'&page={page}'
            print('crawl:', page_url)
            req = requests.get(url, headers)
            req.encoding = 'gb2312'
            if req:
                d = PyQuery(req.text)
                trs = d('.table-bordered tbody tr').items()
                for tr in trs:
                    scheme = tr.find('td:nth-child(4)').text().lower()
                    ip = tr.find('td:nth-child(1)').text()
                    port = tr.find('td:nth-child(2)').text()
                    body = self.verify_proxy(scheme, ip, port, headers, verify_url, timeout=100)
                    if body:
                        return body

    #检验代理ip是否可用
    def verify_proxy(self, scheme, ip, port, headers, verify_url, timeout):
        proxy = {
            'http':scheme + '://' + ip + ':' + port + '/',
            'https':scheme + '://' + ip + ':' + port + '/'
        }
        try:
            print(proxy)
            response = requests.get(verify_url, headers=headers, proxies=proxy, timeout=timeout)
            print(response.status_code)
            if response.status_code == 200:
                return response.json()
        except:
            return None

# %%
a = Proxy_getdata(3, headers)

# %%
#request函数
def httget(url):
    # 防止请求过快
    time.sleep(random.randint(1, 5))
    for i in range(5):
        try:
            print('try using proxies...........')
            body = a.crawl_proxy(url)
            return body
        except:
            time.sleep(120)
    return None

#爬虫函数
def crawl(file_name, url, category1_dict, pages=50):
    with open(file_name, 'w+', encoding='utf-8') as f:
        for category in category1_dict.items():
            category_num = 0
            print(f'*{category[0]} is running...........')
            category_url = url + f'&category%5B%5D={category[1]}'
            # 翻页
            for page in range(1, pages + 1):
                print(f'**{category[0]} page-{page} is running...........')
                page_url = category_url + f'&page={page}'
                page_res = httget(page_url)
                json_data = jsonpath.jsonpath(page_res, '$.data')[0]
                for line in json_data:
                    f.write(json.dumps(line, ensure_ascii=False))
                    f.write('\n')
                category_num += len(json_data)  
                print(f'*{category[0]} is {category_num}>>>>>>>>>>>>>>>>>>>>>')
                if len(json_data) < 5000:
                    break

# %%
rec_add_url = f'https://api.sidelineswap.com/v2/facet_items?include_model=1&page_size=5000&sort=updated'
rec_add = 'quanliang2.json'


crawl(rec_add, rec_add_url, category1_dict, 10)
# Out:
# *Apparel is running...........
# **Apparel page-1 is running...........
# try using proxies...........
# crawl: http://www.ip3366.net/?stype=1&page=0
# {'http': 'https://111.225.153.35:8089/', 'https': 'https://111.225.153.35:8089/'}
# {'http': 'https://111.225.152.188:8089/', 'https': 'https://111.225.152.188:8089/'}
# {'http': 'https://111.225.153.91:8089/', 'https': 'https://111.225.153.91:8089/'}
# {'http': 'https://111.225.153.240:8089/', 'https': 'https://111.225.153.240:8089/'}
# {'http': 'https://111.225.152.29:8089/', 'https': 'https://111.225.152.29:8089/'}
# {'http': 'https://221.226.75.86:55443/', 'https': 'https://221.226.75.86:55443/'}
# {'http': 'https://111.225.152.22:8089/', 'https': 'https://111.225.152.22:8089/'}
# {'http': 'https://111.225.152.99:8089/', 'https': 'https://111.225.152.99:8089/'}
# {'http': 'https://111.225.152.104:8089/', 'https': 'https://111.225.152.104:8089/'}
# 200
# *Apparel is 5000>>>>>>>>>>>>>>>>>>>>>
# ...

# %%
from multiprocessing.dummy import Pool

# 平方函数
def calc_power2(num):
    return num * num

# 定义三个线程池
pool = Pool(3)
# 定义循环数
origin_num = [x for x in range(10)]
# 利用map让线程池中的所有线程‘同时’执行calc_power2函数
result = pool.map(calc_power2, origin_num)
print(f'计算1-10的平方分别为：{result}')
# Out:
# 计算1-10的平方分别为：[0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
#request函数
def httpget(url):
    # 防止请求过快
    time.sleep(random.randint(1, 5))
    for num in range(5):
        try:
            res=requests.get(url=url, headers=headers, timeout=100, verify=False)
            res.encoding='utf-8'
            print(num, res.status_code)
            if res.status_code == 200:
                body = res.json()
                return body
            time.sleep(120)*num
        except Exception as e:
            time.sleep(120)
    Proxy = Proxy_getdata(3, headers)
    print('try using proxies...........')
    body = Proxy.crawl_proxy(url)
    return body

def crawl_seller(file_name, seller):
    seller_list = []
    with open(file_name, 'w+', encoding='utf-8') as f:
        for num,name in enumerate(set(seller)):
            print(f'crawling {name}, it is {num}.........')
            seller_inf = f'https://api.sidelineswap.com/v1/users/{name}?src=locker'
            seller_fee = f'https://api.sidelineswap.com/v1/users/{name}/feedback?&src=locker&page_size=5000'
            seller_list.append(seller_inf)
            seller_list.append(seller_fee)
            pool = Pool(16)
            seller = pool.map(httpget, seller_list)
        return seller

# %%
seller = ['Laxer94151',
 'SportsWearhouse',
 'michael_koenig9',
 'ssmith10',
 'tannerlayton',
 'Reyhaan_9',
 'Klon11']

a = crawl_seller('a', seller)
# Out:
# crawling michael_koenig9, it is 0.........
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 0 200
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 0 200
# crawling Laxer94151, it is 1.........
# ...

# %%
a
# Out:
# [{'data': {'id': 336015,
#    'username': 'michael_koenig9',
#    'avatar_url': 'https://images.sidelineswap.com/production/005/511/042/b957515b3232dee9_small.jpeg',
#    'following': None,
#    'emblems': ['us'],
#    'cover_url': None,
#    'ships_from_country': 'US',
#    'ships_from_region': 'US: Northeast',
#    'follower_count': 1,
#    'following_count': 6,
#    'favorites_count': 29,
#    'feedback_avg': None,
#    'feedback_count': 0,
#    'item_count': {'draft': 0, 'available': 10, 'sold': 1, 'removed': 0},
#    'ship_rate': None,
#    'ship_count': 0,
#    'sales_count': 1,
#    'ship_avg_days': None,
#    'available_bumps': 0,
#    'indexable': False,
#    'power_seller': False,
#    'ambassador': False,
#    'badges': [],
#    'feedback': {'score': None,
#     'recent_count': 0,
#     'count': 0,
#     'count_positive': 0,
#     'count_neutral': 0,
#     'count_negative': 0},
#    'active_vacation': None}},
#  {'data': [],
#   'meta': {'paging': {'total_pages': 0,
# ...
